# %%
import random

# Parámetros del algoritmo genético
TAM_POBLACION = 20  # Tamaño de la población
GENERACIONES = 100    # Número de generaciones
PROB_MUTACION = 0.5  # Probabilidad de mutación (10%)
LONGITUD_CROMOSOMA = 10  # Longitud del cromosoma (número de bits)
VALOR_MAXIMO = 20  # Valor máximo que puede tomar x

# Función objetivo: Maximizar x^2
def funcion_objetivo(x):
    return x ** 2

# Convertir un cromosoma binario a un valor decimal
def binario_a_decimal(cromosoma):
    return int(cromosoma, 2)

# Normalizar el valor decimal al rango [0, VALOR_MAXIMO]
def normalizar(x):
    return (x / (2**LONGITUD_CROMOSOMA - 1)) * VALOR_MAXIMO

# Crear un cromosoma aleatorio (una cadena de bits)
def crear_cromosoma():
    return ''.join(random.choice('01') for _ in range(LONGITUD_CROMOSOMA))

# Crear la población inicial
def crear_poblacion():
    return [crear_cromosoma() for _ in range(TAM_POBLACION)]

# Selección por torneo
def seleccionar_padres_torneo(poblacion):
    torneo_size = 5  # Tamaño del torneo
    padre1 = max(random.sample(poblacion, torneo_size), key=funcion_objetivo_binario)
    padre2 = max(random.sample(poblacion, torneo_size), key=funcion_objetivo_binario)
    return padre1, padre2

# Función objetivo adaptada para usar cromosomas binarios
def funcion_objetivo_binario(cromosoma):
    x = normalizar(binario_a_decimal(cromosoma))  # Normalizamos x
    return funcion_objetivo(x)

# Cruce: Generamos un hijo a partir de dos padres
def cruzar(padre1, padre2):
    punto_cruce = random.randint(1, LONGITUD_CROMOSOMA - 1)
    hijo = padre1[:punto_cruce] + padre2[punto_cruce:]
    return hijo

# Mutación: Cambiar un bit aleatorio
def mutar(cromosoma):
    if random.random() < PROB_MUTACION:
        posicion = random.randint(0, LONGITUD_CROMOSOMA - 1)
        nuevo_bit = '1' if cromosoma[posicion] == '0' else '0'
        cromosoma = cromosoma[:posicion] + nuevo_bit + cromosoma[posicion + 1:]
    return cromosoma

# Algoritmo Genético Principal
def algoritmo_genetico():
    poblacion = crear_poblacion()
    resultados = []

    for generacion in range(GENERACIONES):
        nueva_poblacion = []
        for _ in range(TAM_POBLACION):
            padre1, padre2 = seleccionar_padres_torneo(poblacion)
            hijo = cruzar(padre1, padre2)
            hijo_mutado = mutar(hijo)
            nueva_poblacion.append(hijo_mutado)

        poblacion = nueva_poblacion
        mejor_cromosoma = max(poblacion, key=funcion_objetivo_binario)
        mejor_valor = funcion_objetivo_binario(mejor_cromosoma)
        resultados.append((generacion + 1, mejor_cromosoma, mejor_valor))

    return resultados

# Ejecutar el algoritmo genético
resultados = algoritmo_genetico()
for generacion, cromosoma, valor in resultados:
    print(f"Generación {generacion}: Mejor Cromosoma = {cromosoma}, Valor = {valor:.2f}")
# Out:
# Generación 1: Mejor Cromosoma = 1111110100, Valor = 391.44
# Generación 2: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 3: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 4: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 5: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 6: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 7: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 8: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 9: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 10: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 11: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 12: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 13: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 14: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 15: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 16: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 17: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 18: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 19: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 20: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 21: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 22: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 23: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 24: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 25: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 26: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 27: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 28: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 29: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 30: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 31: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 32: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 33: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 34: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 35: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 36: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 37: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 38: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 39: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 40: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 41: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 42: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 43: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 44: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 45: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 46: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 47: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 48: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 49: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 50: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 51: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 52: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 53: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 54: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 55: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 56: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 57: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 58: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 59: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 60: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 61: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 62: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 63: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 64: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 65: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 66: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 67: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 68: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 69: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 70: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 71: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 72: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 73: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 74: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 75: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 76: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 77: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 78: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 79: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 80: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 81: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 82: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 83: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 84: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 85: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 86: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 87: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 88: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 89: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 90: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 91: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 92: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 93: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 94: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 95: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 96: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 97: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 98: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 99: Mejor Cromosoma = 1111111111, Valor = 400.00
# Generación 100: Mejor Cromosoma = 1111111111, Valor = 400.00
